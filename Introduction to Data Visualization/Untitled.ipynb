# %%
import json
import pandas as pd
file = json.load(open('../Datasets/NYC_Math_Results_2013-107.json'))

# %%
file.save('file.gif')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-ec334e1f01aa> in <module>
# ----> 1 file.save('file.gif')
#
# AttributeError: 'dict' object has no attribute 'save'

# %%
import json

with open("../Datasets/NYC_Math_Results_2013-107.json", "r") as read_file:
    data = json.load(read_file)

# %%
pd.DataFrame(file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-0332ebb98fc4> in <module>
# ----> 1 pd.DataFrame(file)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
pd.DataFrame(pd.io.json.json_normalize(file))
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                                 data meta.view.id  \
# 0  [[row-4pnu~riam-k4xm, 00000000-0000-0000-77D6-...    x4ai-kstz
#
#                            meta.view.name  meta.view.averageRating  \
# 0  2013-2017 School Math Results - Gender                        0
#
#   meta.view.category  meta.view.createdAt meta.view.displayType  \
# 0          Education           1506355113                 table
#
#    meta.view.downloadCount  meta.view.hideFromCatalog  \
# 0                     1106                      False
#
#    meta.view.hideFromDataJson  ...  meta.view.owner.type  \
# 0                       False  ...           interactive
#
#   meta.view.owner.userSegment  meta.view.rights  meta.view.tableAuthor.id  \
# ...

# %%
file
# Out:
# {'meta': {'view': {'id': 'x4ai-kstz',
#    'name': '2013-2017 School Math Results - Gender',
#    'averageRating': 0,
#    'category': 'Education',
#    'createdAt': 1506355113,
#    'displayType': 'table',
#    'downloadCount': 1106,
#    'hideFromCatalog': False,
#    'hideFromDataJson': False,
#    'indexUpdatedAt': 1536602847,
#    'locale': 'en_US',
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 26867540,
#    'provenance': 'official',
#    'publicationAppendEnabled': False,
#    'publicationDate': 1506356065,
#    'publicationGroup': 14486436,
#    'publicationStage': 'published',
#    'rowClass': '',
#    'rowsUpdatedAt': 1506355132,
#    'rowsUpdatedBy': 'fn2b-3u6b',
#    'tableId': 14486436,
#    'totalTimesRated': 0,
#    'viewCount': 370,
#    'viewLastModified': 1549924017,
#    'viewType': 'tabular',
#    'approvals': [{'reviewedAt': 1506356065,
#      'reviewedAutomatically': True,
#      'state': 'approved',
#      'submissionId': 1068765,
# ...
